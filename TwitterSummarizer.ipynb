# %% [markdown]
# # The Tweet Summarizer
#
# This application takes in raw tweet objects from a database, then extracts summaries and
# entities from them using rule-based and machine learning-based approaches.
#
# *This is a demonstration attempt at detecting "events" from a hand-picked selection of
# Twitter accounts. Therefore, this demo invoked limited use of advanced spam- and noise-detection
# techniques, since it is assumed that this dataset will be free from such things.
#
# ## The Process
#
# In order to filter raw tweet objects for noise, then summarize them and extract their
# natural entities, we will use the following approach.
#
# Before we begin the feature extraction process, we need to connect to the database
# and pull down information. Two things to note as we begin this process:
# * database connection information is held in a separate configuration file inside "/Users/
# $User/Quantum/Event Detector/Twitter Event Detector/"
# * since the idea is to gather real-time data, the idea would be to poll the database every
# 15-45 seconds. However, since we are merely testing the concept here, initial polls will be
# conducted every 120-300 seconds.
#
# Here, we connect to the database and read the last 100 entries (changeable in the first variable).

# %%
number_of_rows = 100

import configparser
import os
import psycopg2

def config_file_reader(API_caller: str) -> tuple:
    """
    A common configuration file reader.
    
    Reads data from a common configuration file, determining which fields to call depending 
    on the API caller passed to it.
    
    :param API_caller:(str) the name of the service calling this API
     
    :return: (tuple) a tuple of strings of each configuration returned for the called service
    """
    # "/Users/$User/Quantum/Event Detector/Twitter Event Detector/". 
    home_directory_path = os.path.expanduser("~")
    logger_directory_path = os.path.join(home_directory_path, "Quantum", "Event Detector", 
                                         "Twitter Event Detector", "Logs")
    config_directory_path = os.path.join(home_directory_path, "Quantum", "Event Detector", 
                                         "Twitter Event Detector", "Common")
    config_file_path = os.path.join(config_directory_path, "config.ini")

    # instantiates the configuration parser
    config = configparser.ConfigParser()
    
    # if config files exists, proceed: else, create directory structure, then fail gracefully
    if os.path.exists(config_file_path):
        config.read(config_file_path)
    else:
        os.makedirs(config_directory_path)
        print("No config file found in " + config_directory_path + 
              ". Please place a configuration file into this directory and try again.")
        
    if API_caller == "data_access_object":
        database_type = config["DATABASE"]["type"]
        database_host = config["DATABASE"]["host"]
        database_name = config["DATABASE"]["database_name"]
        database_user = config["DATABASE"]["user"]
        database_password = config["DATABASE"]["password"]
        database_instance_id = config["DATABASE"]["database_instance_id"]
        database_port = config["DATABASE"]["database_port"]
        return database_type, database_host, database_name, database_user, database_password, \
               database_instance_id, database_port
    elif API_caller == "logger_setup":
        return logger_directory_path,
    elif API_caller == "languages":
        languages = config["LANGUAGES"]["supported_languages"]
        return languages
    elif API_caller == "account_metadata_importer":
        # this API call only requires the directory path to the config file (which stores a CSV file necessary)
        return config_directory_path,
    else:
        print("Error on reading config file: no API caller specified")
        
def raw_tweet_database_connector():
    """
    Creates and returns a connection object to a PostgreSQL database.

    :param host: (str) the hostname or IP address
    :param database: (str) the database name
    :param user: (str) the user name
    :param password: (str) the database password
    :param port: (int) the port number
    :return: (psycopg2.connect) a PostgreSQL connection object
    """
    config = config_file_reader("data_access_object")
    database_type, database_host, database_name, database_user, database_password, \
        database_instance_id, database_port = config
    
    try:
        connection = psycopg2.connect(host=database_host, dbname=database_name, user=database_user, 
                                      password=database_password, port=database_port)
        return connection
    except psycopg2.OperationalError:
        print('Database connection error')
        
def raw_tweet_database_reader() -> list:
    """
    Reads the last 100 entries in the Raw Tweet Database. 
    
    :return: (pandas dataframe) a dataframe containing the last 100 entries in the Raw Tweet Database 
    """
    # calls the database connector
    connection = raw_tweet_database_connector()
    cursor = connection.cursor()
    
    sql = "SELECT tweet_time_created, tweet_uid, tweet_text, tweet_source, reply_tweet_uid, reply_tweet_count, " \
      "quote_tweet, quote_tweet_uid, quote_tweet_text, quote_tweet_count, retweet_tweet_status,  " \
      "retweet_tweet_count, tweet_language, user_uid, user_name, user_screen_name, user_description, " \
      "user_verification, user_follower_count, user_friends_count, user_statuses_count, user_time_created, " \
      "tweet_coordinates, tweet_place, tweet_place_country_code, tweet_place_bounding_box, " \
      "tweet_hashtags, tweet_urls, tweet_symbols, tweet_user_mentions, user_location FROM twitter_posts " \
      "ORDER BY tweet_time_created DESC LIMIT %s;"
    
    cursor.execute(sql, (number_of_rows,))
    return cursor.fetchall()

fetched_results = raw_tweet_database_reader()

# %%
# shows one row of data from the database
print(*fetched_results[2], sep='\n\n')
# Out:
# 2020-03-28 03:15:02
#
# 1243738342254133249
#
# Dr Sirous Asgari was accused of stealing trade secrets and breaking Washington's sanctions against Iran while working on a research project at Case Western Reserve University in Ohio
# https://t.co/6grbfRr5i9
#
# <a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>
#
# None
#
# 0
#
# False
#
# None
#
# None
#
# 0
#
# None
#
# 0
#
# en
#
# 2373735295
#
# Middle East Eye
#
# MiddleEastEye
#
# Your eye on the ground. Independent Middle East and North Africa news
#
# True
#
# 222027
#
# 286
#
# 250660
#
# 2014-03-05 13:05:36
#
# None
#
# None
#
# None
#
# None
#
# None
#
# ['http://ow.ly/vNHJ50yY68m']
#
# None
#
# None
#
# None

# %% [markdown]
# We now need to initialize spaCy and load all of its dependencies.

# %%
import spacy

# imports the medium-sized English-language spaCy trained module, with vectors
nlp = spacy.load('en_core_web_md')

# %% [markdown]
# As the first step of our text processing, we need to extract all of the named
# entities from the tweet text. We will do this by first running the entire collected stream
# through a spaCy pipeline.
#
# We start by creating a list of only the tweet text data, then running that list through spaCy.

# %%
# we create a tuple of the data we want spaCy to ingest from the tweet_text and user_location fields
fetched_tweet_text = []
fetched_user_location = []
fetched_data_tuples = []
for _ in fetched_results:
    # list index of text tweet data within each tweet object
    fetched_tweet_text.append(_[2])   
    fetched_user_location.append(_[-1])

# create a list of tuples of (tweet_text, user_location)
for text, location in zip(fetched_tweet_text, fetched_user_location):
    fetched_data_tuples.append((text, {'user_location': location}))

# creates a spaCy pipe, which processes input text data as a stream, returning a Doc object for each of those Docs
docs = list(nlp.pipe(fetched_data_tuples, as_tuples=True))

# prints out Doc data - only way to show context is to print during pipe creation. 
for doc, context in nlp.pipe(fetched_data_tuples, as_tuples=True):
    print(doc.text)
    print('\t', context)
    for ent in doc.ents:
        print('\t', ent.text, ent.label_)
    print('---\n')
# Out:
# The Shangri-La Dialogue, a high-profile regional security forum held annually in Singapore, has been canceled due to the coronavirus outbreak https://t.co/7qP0mc4N69
# 	 {'user_location': 'New York and the World'}
# 	 The Shangri-La Dialogue ORG
# 	 annually DATE
# 	 Singapore GPE
# ---
#
# #NSTnation Non-compliance with the Movement Control Order #MCO has led to several #Covid19 cases in the state, said #Sabah health department director Datuk Dr Christina Rundi.
# #stayathome, #dudukrumah
#
# https://t.co/Yo3sWsBpNz
# 	 {'user_location': 'Malaysia'}
# 	 MCO ORG
# 	 several #Covid19 MONEY
# 	 # CARDINAL
# 	 Sabah PERSON
# 	 Datuk Dr PERSON
# 	 Christina Rundi PERSON
# 	 stayathome PERSON
# 	 dudukrumah PERSON
# ---
#
# Dr Sirous Asgari was accused of stealing trade secrets and breaking Washington's sanctions against Iran while working on a research project at Case Western Reserve University in Ohio
# https://t.co/6grbfRr5i9
# 	 {'user_location': 'None'}
# 	 Dr Sirous Asgari PERSON
# 	 Washington GPE
# 	 Iran GPE
# 	 Case Western Reserve University ORG
# 	 Ohio GPE
# ---
#
# Okinawa sees fall in foreign visitors amid pandemic https://t.co/h5P6mIt6cI
# 	 {'user_location': 'Tokyo'}
# 	 Okinawa GPE
# ---
#
# New date for Tokyo @Olympics 'won't satisfy everybody', says @sebcoe
#
# READ: https://t.co/QY5YDnQTUW
#
# #CautionYesPanicNo #TokyoOlympics #Olympics #SebastianCoe #WorldAthletics #coronavirus #COVID19 https://t.co/LG3ps7MaXx
# 	 {'user_location': 'New Delhi'}
# 	 Tokyo @Olympics ' ORG
# 	 #CautionYesPanicNo #TokyoOlympics MONEY
# 	 #SebastianCoe MONEY
# ---
#
# Trump invokes the Defense Production Act to require General Motors to build ventilators for coronavirus patients. The act gives the president power to expand industrial production of key materials or products https://t.co/kO0eZWctVQ https://t.co/421lFd1N6c
# 	 {'user_location': 'Around the world'}
# 	 Trump ORG
# 	 the Defense Production Act LAW
# 	 General Motors ORG
# ---
#
# Coronavirus: Kiwi man offers Dettol sanitiser for $60 per bottle https://t.co/U7jDZ4jOw4 https://t.co/DjT1UQ56H8
# 	 {'user_location': 'New Zealand'}
# 	 Kiwi PRODUCT
# 	 Dettol ORG
# 	 60 MONEY
# ---
#
# #NSTsports Dybala says #Covid19 left him struggling for breath https://t.co/8Uze4N4Ios
# 	 {'user_location': 'Malaysia'}
# 	 Dybala PERSON
# 	 Covid19 MONEY
# ---
#
# #NSTnation The Health Ministry has set up a special committee to conduct audit on patients who succumbed to #Covid19 in hospitals.
#  https://t.co/0jTwhC5iAf
# 	 {'user_location': 'Malaysia'}
# 	 The Health Ministry ORG
# 	 #Covid19 MONEY
# ---
#
# European airlines resist mounting coronavirus refund claims https://t.co/VgvxdTd8Jr https://t.co/rpHwK303xO
# 	 {'user_location': 'Around the world'}
# 	 European NORP
# 	 https://t.co/VgvxdTd8Jr ORG
# ---
#
# Top headlines at this hour
#
# For more, visit 👉 https://t.co/Tqw9O0nFTh https://t.co/bGCYIUGBa3
# 	 {'user_location': 'New Delhi'}
# 	 this hour TIME
# ---
#
# #Coronavirus | India is all set to join World Health Organisation’s multi-country “Solidarity trial” aimed at rapid global search for drugs to treat #COVID19.
# https://t.co/B37Bib3kX5
# 	 {'user_location': 'Chennai, India'}
# 	 Coronavirus PERSON
# 	 India GPE
# 	 World Health Organisation ORG
# 	 Solidarity ORG
# ---
#
# Blue chips hardest hit by foreign exits https://t.co/EYjrbnCNDW
# 	 {'user_location': 'Kenya'}
# ---
#
# Whatever it takes
#
# RBI tries to arrest an economic slide
#
# Read today's TOI Edit 👇
#
# https://t.co/a7HQnyk6Ds https://t.co/w3ErEhXZJ7
# 	 {'user_location': 'New Delhi'}
# 	 today DATE
# 	 TOI Edit 👇 ORG
# ---
#
# #NSTworld Watch: Paris opera singer belts out balcony tunes amid #Covid19 lockdown https://t.co/QK7NhOmcE4
# 	 {'user_location': 'Malaysia'}
# 	 # CARDINAL
# 	 Paris GPE
# ---
#
# “Patriotism and self-protection in the midst of the COVID-19 pandemic demand the temporary ban on overseas deployment of Filipino healthcare professionals and workers like physicians, nurses, and laboratory technicians,” Lagman said. | @khallareINQ https://t.co/sDsge2buz6
# 	 {'user_location': 'Makati City'}
# 	 Patriotism and self-protection in the midst of the COVID-19 pandemic demand the temporary ban on overseas deployment of Filipino healthcare professionals and workers like physicians, nurses, and laboratory technicians WORK_OF_ART
# 	 Lagman PERSON
# ---
#
# #NSTworld Five members of the US #Congress have tested positive for the #Covid19 #coronavirus, and more than two dozen others have said they are self-quarantining in hopes of limiting the spread of the pandemic.
#
#  https://t.co/w7oHN3wh2R
# 	 {'user_location': 'Malaysia'}
# 	 US GPE
# 	 Congress ORG
# 	 #Covid19 # MONEY
# 	 more than two dozen CARDINAL
# ---
#
# Sustaining trust in resilient real estate https://t.co/8tKJy24CAo
# 	 {'user_location': 'Makati City'}
# ---
#
# A federal judge in California is considering an emergency order to release children who were apprehended crossing into the U.S. alone, in order to protect them from contracting COVID-19. https://t.co/3GWkuTG2Vp
# 	 {'user_location': 'None'}
# 	 California GPE
# 	 U.S. GPE
# ---
#
# #NSTworld #Brunei reported its first #Covid19 coronavirus death on Saturday, that of a 64-year-old man.
#
# https://t.co/SXYrgyUher
# 	 {'user_location': 'Malaysia'}
# 	 Brunei GPE
# 	 first ORDINAL
# 	 Covid19 MONEY
# 	 Saturday DATE
# ---
#
# Milan hospital coronavirus squad battles the odds to save a life https://t.co/FF77xN1T9A https://t.co/jaHxLVO2FO
# 	 {'user_location': 'Around the world'}
# 	 Milan GPE
# 	 https://t.co/FF77xN1T9A https://t.co/jaHxLVO2FO PERSON
# ---
#
# "We’re working in a unique time and she helps us stay grounded." https://t.co/EXkX8acXU6
# 	 {'user_location': 'New York City / Worldwide'}
# ---
#
# You share your birthday with
#
# #LadyGaga https://t.co/YSUrAMEdYj
# 	 {'user_location': 'New Delhi'}
# 	 LadyGaga PERSON
# ---
#
# SoftBank has said it's not obligated to go through with the deal. https://t.co/OspVWSMM1O
# 	 {'user_location': 'New York and the World'}
# 	 SoftBank ORG
# ---
#
# World War II-inspired posters remind you to stay inside and wash your hands https://t.co/mImf7v17Sy
# 	 {'user_location': 'Washington, DC'}
# 	 World War II EVENT
# ---
#
# In print today: US, Italy surpass China in infections; India’s urban poor fight for survival; False belief that a poison fights the virus kills hundreds in Iran. https://t.co/M4JY2H3Gqu
# 	 {'user_location': 'United Arab Emirates'}
# 	 today DATE
# 	 US GPE
# 	 Italy GPE
# 	 China GPE
# 	 India GPE
# 	 hundreds CARDINAL
# 	 Iran GPE
# 	 https://t.co/M4JY2H3Gqu PERSON
# ---
#
# "Don't call the woman in Michigan," Trump said while discussing Pence's White House Coronavirus Task Force work.
#
# That governor – Gretchen Whitmer – replied on Twitter that "right now, we all need to be focused on fighting the virus, not each other." https://t.co/D1keuVfUPh
# 	 {'user_location': 'USA TODAY HQ, McLean, Va.'}
# 	 Michigan GPE
# 	 Trump ORG
# 	 Pence ORG
# 	 White House ORG
# 	 Gretchen Whitmer PERSON
# 	 Twitter ORG
# ---
#
# U.S. House will have panel overseeing coronavirus aid law expenditures: Pelosi https://t.co/jMkOIXFlsN https://t.co/fUISMvDarK
# 	 {'user_location': 'Around the world'}
# 	 U.S. House ORG
# 	 Pelosi PERSON
# ---
#
# Coronavirus is a “personal nightmare” for people with OCD and anxiety disorders. https://t.co/Z2LcPjPKCr
# 	 {'user_location': 'New York, NY'}
# 	 Coronavirus ORG
# ---
#
# Across the U.S., state attorneys general said this week that they had been flooded with complaints of price gouging and profiteering on items like hand sanitizer, disinfectant wipes and masks https://t.co/abCvNhpD24
# 	 {'user_location': 'New York City'}
# 	 U.S. GPE
# 	 this week DATE
# ---
#
# Manhattan’s crowds have disappeared, leaving shuttered businesses, an empty rush hour and only the sounds of HVAC systems audible on quiet streets https://t.co/gDdkn8DYjj
# 	 {'user_location': 'New York, NY'}
# 	 Manhattan GPE
# ---
#
# Commentary: Leave the COVID-19 data analysis to the experts https://t.co/4YC1Wk06vh
# 	 {'user_location': 'Tokyo'}
# ---
#
# The words “betrayal” and “traitor” are the most popular ones on social media to describe Gantz’s breach of faith https://t.co/8we3HIUMl6
# 	 {'user_location': 'None'}
# 	 Gantz PERSON
# ---
#
# The countries that have done best in containing the virus – Taiwan and South Korea – are democracies that combine high levels of trust in the authorities with a commitment to rapidly disseminating reliable information (via @bopinion) https://t.co/pvZnynn2L1
# 	 {'user_location': 'New York and the World'}
# 	 Taiwan GPE
# 	 South Korea GPE
# ---
#
# Coronavirus: Wellington Phoenix coaching staff member tests positive: report https://t.co/Znr8KjhYqv https://t.co/gpro1v4fpd
# 	 {'user_location': 'New Zealand'}
# 	 Coronavirus ORG
# 	 Wellington GPE
# 	 Phoenix GPE
# ---
#
# Half of the 100 COVID-19 isolation rooms needed by the Western Regional Health Authority have been identified in Montego Bay, Health and Wellness Minister Dr Christopher Tufton has said. Read more: https://t.co/4A2XmrKyCX #GLNRToday https://t.co/b2ouC5Fnll
# 	 {'user_location': 'Jamaica'}
# 	 Half CARDINAL
# 	 100 CARDINAL
# 	 the Western Regional Health Authority ORG
# 	 Montego Bay GPE
# 	 Dr Christopher Tufton PERSON
# ---
#
# In Siaya County, Distinction Hotel, Siaya County Club, Camunya in Ugunja, Savannah, Chez Mbago, Switel in Bondo, Pride Kings also in Bondo are some of the hardest hit, having been forced to downsize their workforce. https://t.co/diJxfZtztR
# 	 {'user_location': 'Kenya'}
# 	 Siaya County GPE
# 	 Distinction Hotel ORG
# 	 Siaya County Club ORG
# 	 Camunya GPE
# 	 Ugunja GPE
# 	 Savannah GPE
# 	 Chez Mbago GPE
# 	 Switel FAC
# 	 Bondo GPE
# 	 Pride Kings ORG
# 	 Bondo ORG
# 	 https://t.co/diJxfZtztR PERSON
# ---
#
# Why ventilators are a frontline weapon against Covid-19
#
# Read this and more in today's #TimesTop10: Special stories of the day, curated by our editors, delivered to your inbox
#
# Click here to subscribe 👇
#
# https://t.co/bxkygWxBHF https://t.co/mYqpVj8iXP
# 	 {'user_location': 'New Delhi'}
# 	 today DATE
# 	 the day DATE
# 	 👇 CARDINAL
# ---
#
# Parents okay with move, but some wonder about efficacy
# https://t.co/e6GyKr06Mp
# 	 {'user_location': 'Singapore'}
# ---
#
# Our daily crossword puzzle https://t.co/BIJNoPl5hJ
# 	 {'user_location': 'El Segundo, CA'}
# 	 daily DATE
# ---
#
# The Rotterdam Philharmonic Orchestra virtually stages Beethoven's 'Ode to Joy' with 19 musicians playing their individual parts from their homes https://t.co/tE0FhJHmqP
# 	 {'user_location': 'Around the world'}
# 	 The Rotterdam Philharmonic Orchestra ORG
# 	 Beethoven PERSON
# 	 'Ode to Joy' WORK_OF_ART
# 	 19 CARDINAL
# ---
#
# Texas firm accused of price-gouging by auctioning 750,000 medical masks https://t.co/4bylu7XRB1 https://t.co/3GX4dEAMOF
# 	 {'user_location': 'New York, NY'}
# 	 Texas GPE
# 	 750,000 CARDINAL
# ---
#
# British Health Secretary Matt Hancock has tested positive for the new coronavirus. https://t.co/5c8dmg9gks
# 	 {'user_location': 'Makati City'}
# 	 British NORP
# 	 Matt Hancock PERSON
# ---
#
# This is how 3M doubled N95 mask production practically overnight to fight coronavirus https://t.co/Fhdha7tQrN via @BW
# 	 {'user_location': 'New York and the World'}
# 	 3 CARDINAL
# 	 N95 ORG
# 	 https://t.co/Fhdha7tQrN PRODUCT
# ---
#
# Pope Francis meditates on the calming of the storm from the Gospel of Mark during the "Urbi et Orbi" amid the coronavirus pandemic on Saturday, March 28. https://t.co/4YmsIM2mga
# 	 {'user_location': 'Makati City'}
# 	 Pope Francis PERSON
# 	 the Gospel of Mark ORG
# 	 Saturday, March 28 DATE
# ---
#
# Attorney General insists COVID containment measures are constitutional - https://t.co/A7yiSNNmQ1
# 	 {'user_location': 'Jamaica'}
# 	 COVID ORG
# ---
#
# "As I write these words, enclosed with my wife in quarantine, I should be on a plane taking me to Israel," Samuel Heilman writes
#
# https://t.co/NGf9JYVbcI
# 	 {'user_location': 'Israel'}
# 	 Israel GPE
# 	 Samuel Heilman PERSON
# ---
#
# From Khmer Rouge to Khmer Riche: is Hun Sen losing his decades-long grip on Cambodia’s corrupt politics? https://t.co/WybNGjaHfo
# 	 {'user_location': 'Hong Kong'}
# 	 Khmer Rouge ORG
# 	 Khmer Riche ORG
# 	 Hun Sen PERSON
# 	 decades-long DATE
# 	 Cambodia GPE
# ---
#
# Delhi: People exercise #SocialDistancing while making purchases at vegetable and fruit stores &amp; dairies. Visuals from Mandi House area.
#
# (Pics: ANI)
#
# No new confirmed cases of the #COVID_19 were reported Friday in Wuhan, the former hardest-hit city in central China's Hubei Province. Hubei has so far reported a total of 67,801 confirmed COVID-19 cases, including 50,006 in Wuhan. https://t.co/6rG6jFTZHW
# 	 {'user_location': 'Beijing, China'}
# 	 Friday DATE
# 	 Wuhan GPE
# 	 China GPE
# 	 Hubei Province GPE
# 	 Hubei GPE
# 	 67,801 CARDINAL
# 	 50,006 CARDINAL
# 	 Wuhan GPE
# ---
#
# A one-year-old girl is the first confirmed coronavirus disease 2019 (COVID-19) patient in Oriental Mindoro, Governor Humerlito Dolor announced. https://t.co/uJFSUKSqJu
# 	 {'user_location': 'Makati City'}
# 	 one-year-old DATE
# 	 first ORDINAL
# 	 2019 DATE
# 	 Oriental NORP
# 	 Mindoro PERSON
# 	 Humerlito Dolor PERSON
# ---
#
# .@NBCNews found more than 10 security companies in the U.S., Europe, and China that are marketing tech as capable of picking out who in a crowd is likely to have a fever, and thus a possible coronavirus case.
#
# But experts say the tech is imprecise. https://t.co/hPdQE69AmZ
# 	 {'user_location': 'New York, NY'}
# 	 more than 10 CARDINAL
# 	 U.S. GPE
# 	 Europe LOC
# 	 China GPE
# ---
#
# Thousands of Ukrainians wait at Polish border to get home https://t.co/BTqlhPlERa https://t.co/uOjZW6j6sw
# 	 {'user_location': 'Around the world'}
# 	 Thousands CARDINAL
# 	 Ukrainians NORP
# 	 Polish NORP
# ---
#
# Give me more time to pay fine, ‘husband beater’ says
# https://t.co/LIomqftKri
# 	 {'user_location': 'Kenya'}
# ---
#
# #Coronavirus | Rajiv Gauba has asked the States to effectively monitor 15 lakh international air passengers who came from January 18 to March 23 as there appeared to be a “gap” between the actual monitoring.
# https://t.co/EikMnxO2IB
# 	 {'user_location': 'Chennai, India'}
# 	 Rajiv Gauba PERSON
# 	 States GPE
# 	 15 lakh MONEY
# 	 January 18 to March 23 DATE
# ---
#
# Documenting the spread of Covid-19 in Eastern Africa  #COVID19KE #NationNewsplex https://t.co/DFVvy67lwJ
# 	 {'user_location': 'Kenya'}
# 	 Eastern Africa LOC
# 	 NationNewsplex ORG
# ---
#
# Unshackle them
#
# Essential supply chains caught in lockdown tangle
#
# Read today's TOI Edit 👇
#
# https://t.co/3hNgo39UZQ https://t.co/vV2301bdBd
# 	 {'user_location': 'New Delhi'}
# 	 today DATE
# 	 TOI Edit 👇 ORG
# ---
#
# A Serbian court has sentenced a man to three years in jail for flouting self-isolation orders. https://t.co/kYH1W6zgwx
# 	 {'user_location': 'Makati City'}
# 	 Serbian NORP
# 	 three years DATE
# ---
#
# Coronavirus: Wellington Phoenix coaching staff member tests positive: report https://t.co/Sy3cTkrZBD https://t.co/dVgK05naoD
# 	 {'user_location': 'New Zealand'}
# 	 Coronavirus ORG
# 	 Wellington GPE
# 	 Phoenix GPE
# ---
#
# Cases of community transmission of COVID-19 in NSW have increased to 170 as NSW Health urges people to practice social distancing and isolation measures https://t.co/jj0fKjabTg
# 	 {'user_location': 'Sydney, Australia'}
# 	 NSW ORG
# 	 170 CARDINAL
# 	 NSW Health ORG
# ---
#
# 	 Coronavirus ORG
# 	 New Zealand's GPE
# 	 451 CARDINAL
# ---
#
# The mayor of Cataingan town in Masbate province said on Friday night that the entire household of the patient considered a PUM for coronavirus disease (COVID-19) was placed under watch, according to a recommendation by the Rural Health Unit. https://t.co/YGyUaJXZdi
# 	 {'user_location': 'Makati City'}
# 	 Cataingan ORG
# 	 Masbate province GPE
# 	 Friday DATE
# 	 night TIME
# 	 the Rural Health Unit ORG
# ---
#
# Wellington Urban Motorway partially closed after diesel spill from truck crash https://t.co/IZBRKB7y4x
# 	 {'user_location': 'New Zealand'}
# 	 Wellington Urban Motorway GPE
# ---
#
# RBI cuts rate by 75 bps, steepest in over 10 years; you can defer EMIs by 3 months https://t.co/d5RWjMhm2p via
# @TOIBusiness https://t.co/HGKCL4S3DI
# 	 {'user_location': 'New Delhi'}
# 	 75 CARDINAL
# 	 over 10 years DATE
# 	 3 months DATE
# 	 @TOIBusiness ORG
# ---
#
# In 10 days, this teacher went from a mild fever to a medically induced coma https://t.co/BlxJwLkW3r
# 	 {'user_location': 'Washington, DC'}
# 	 10 days DATE
# ---
#
# RBI cuts rate by 75 bps, steepest in over 10 years; you can defer EMIs by 3 months https://t.co/d5RWjMhm2p via @TOIBusiness
# 	 {'user_location': 'New Delhi'}
# 	 75 CARDINAL
# 	 over 10 years DATE
# 	 3 months DATE
# 	 @TOIBusiness ORG
# ---
#
# Australia tightens quarantine rules to combat coronavirus, warns of fines https://t.co/0rRrycdkzi https://t.co/WQK53uFBZP
# 	 {'user_location': 'Around the world'}
# 	 Australia GPE
# ---
#
# Dr. Nagarajan's visa only allows him to work at the South Carolina hospital that hired him. He wants to be near the outbreak's epicenter in New York — but a USCIS slowdown means he can't easily transfer his visa.
#
# "I wish I can go and help there," he said. https://t.co/itvUvBN0DB
# 	 {'user_location': 'None'}
# 	 Nagarajan PERSON
# 	 South Carolina GPE
# 	 New York GPE
# 	 USCIS ORG
# ---
#
# Who PH celebs would love to be quarantined with https://t.co/TGyXWUbvqf
# 	 {'user_location': 'Makati City'}
# ---
#
# Anthony Joshua’s Promoter Has a Plan for Boxing Match to Go Ahead https://t.co/4gCDhVj3a7
# 	 {'user_location': 'New York and the World'}
# 	 Anthony Joshua PERSON
# 	 Promoter Has a Plan for Boxing Match to Go Ahead WORK_OF_ART
# ---
#
# Coronavirus: Vietnam stockpiles rice as outbreak spreads and food security concerns grow https://t.co/jgfbtlN67l
# 	 {'user_location': 'Hong Kong'}
# 	 Coronavirus PERSON
# 	 Vietnam GPE
# ---
#
# Crafty ways to beat virus blues: Get creative with small-group workshops https://t.co/0g6cMcnWyX
# 	 {'user_location': 'Singapore'}
# ---
#
# Stranded by coronavirus lockdown, India migrant workers walk home https://t.co/3MwNgNDCEY
# 	 {'user_location': 'Singapore'}
# 	 India GPE
# ---
#
# Brazil bars foreigners as President Bolsonaro urges end to social distancing https://t.co/fBsxnYe8lp
# 	 {'user_location': 'Singapore'}
# 	 Brazil GPE
# 	 Bolsonaro PERSON
# 	 https://t.co/fBsxnYe8lp ORG
# ---
#
# Buzzzzzzzzz
#
# Stay at home.
#
# Buzzzzzzzzz
#
# https://t.co/X76EumA6qW
# 	 {'user_location': 'El Segundo, CA'}
# ---
#
# Cat found infected with coronavirus in Belgium https://t.co/pdWlfyS8wd
# 	 {'user_location': 'Tokyo'}
# 	 Belgium GPE
# ---
#
# Why the US is leading the world in confirmed coronavirus cases https://t.co/yTu7DjtmPJ via @TOIWorld
#
# #CautionYesPanicNo #CoronavirusOutbreak #Covid19
# 	 {'user_location': 'New Delhi'}
# 	 US GPE
# 	 @TOIWorld ORG
# 	 #CautionYesPanicNo #CoronavirusOutbreak #Covid19 MONEY
# ---
#
# From @WSJopinion: To restart the economy, the government needs to set up immunity registries similar to those for childhood diseases, writes @BillCassidy and Dr. Christopher Mores https://t.co/chvBoDBlKo
# 	 {'user_location': 'New York, NY'}
# 	 @WSJopinion CARDINAL
# 	 @BillCassidy ORG
# 	 Christopher Mores https://t.co/chvBoDBlKo PERSON
# ---
#
# The irresistible force of the coronavirus collided with the immovable object of the federation this week, revealing both the limits of prime ministerial authority, and the fragility of our very system of governance | ANALYSIS https://t.co/1LECMGnSYX
# 	 {'user_location': 'Melbourne, Australia'}
# 	 this week DATE
# ---
#
# Activists from across the occupied territory have reported a spike in settler attacks since a state of emergency was declared due to the coronavirus pandemic https://t.co/ZMJwochLle
# 	 {'user_location': 'None'}
# ---

# %% [markdown]
# All of the processing on the Docs objects has already been done:: all that's left now is
# to use the data.

# %% [markdown]
# We need to be able to process location data from tweets that don't contain it. Many will
# have the data as part of the tweet text, but many won't. There are a few reasons for
# this:
#
# * context context
# If a tweet is about a person, or about a well known event, location data is not
# necessary, nor is it necessarily helpful.
#
# * user context
# If a tweet is from a small source, a local newspaper, or even a national source, often
# the context is that the _source_ is local.
#
# For the first reason, we must come up with ways to make sure that the context of the
# tweet overrides the location data, even if it is provided. We need to come up with
# ways of doing this, because of the steps we're going to take for the second reason.
#
# For the second reason, we can inject the tweet user's location data if no other
# location data exists in the tweet text.
#
# In this code block, we try to complete the entire merging process, making the context Doc part of the tweet_text Doc.

# %%
def adding_user_location():
    """
    Uses the provided 'context' data added to a spaCy Doc, runs it through its 
    own NLP pipeline to extract entity data, then returns a Doc object that 
    contains NLP metadata to be added to the original Doc object it was derived from.
    
    param: (dict)
    
    returns: (spaCy Doc)
    """
    # list of Doc objects with context-added location data
    docs_with_gpe = []
    
    for doc in docs:
        ents = [(ent.text, ent.label_) for ent in doc[0].ents]
        # code block to detemine of spaCy detected entities contain GPE
        contains_GPE = False
        if ents:
            for e in ents:
                if e[1] == "GPE":
                    contains_GPE = True
        if contains_GPE is False:
            doc_with_gpe = doc_reconstructor(doc)
            docs_with_gpe.append(doc_with_gpe)
        else:
            docs_with_gpe.append(doc[0])
    return docs_with_gpe
        
        
def doc_reconstructor(original_doc):
    """
    Takes the data from the old Doc (text and context) and combines it to make and return a new Doc.
    """
    combined_text_and_context = str(original_doc[0]) + '. ' + str(original_doc[1]['user_location']) + '.'
    doc = nlp(combined_text_and_context)
    return doc

docs_with_gpe = adding_user_location()

# %%
for doc in docs_with_gpe:
    print(doc)
    print(type(doc))
    print('\n---\n')
# Out:
# The Shangri-La Dialogue, a high-profile regional security forum held annually in Singapore, has been canceled due to the coronavirus outbreak https://t.co/7qP0mc4N69
# <class 'spacy.tokens.doc.Doc'>
#
# ---
#

# <class 'spacy.tokens.doc.Doc'>
#
# ---
#
# In 10 days, this teacher went from a mild fever to a medically induced coma https://t.co/BlxJwLkW3r. Washington, DC.
# <class 'spacy.tokens.doc.Doc'>
#
# ---
#
# RBI cuts rate by 75 bps, steepest in over 10 years; you can defer EMIs by 3 months https://t.co/d5RWjMhm2p via @TOIBusiness. New Delhi.
# <class 'spacy.tokens.doc.Doc'>
#
# ---
#
# Australia tightens quarantine rules to combat coronavirus, warns of fines https://t.co/0rRrycdkzi https://t.co/WQK53uFBZP
# <class 'spacy.tokens.doc.Doc'>
#
# ---
#
# Dr. Nagarajan's visa only allows him to work at the South Carolina hospital that hired him. He wants to be near the outbreak's epicenter in New York — but a USCIS slowdown means he can't easily transfer his visa.
#
# "I wish I can go and help there," he said. https://t.co/itvUvBN0DB
# <class 'spacy.tokens.doc.Doc'>
#
# ---
#
# Who PH celebs would love to be quarantined with https://t.co/TGyXWUbvqf. Makati City.
# <class 'spacy.tokens.doc.Doc'>
#
# ---
#
# Anthony Joshua’s Promoter Has a Plan for Boxing Match to Go Ahead https://t.co/4gCDhVj3a7. New York and the World.
# <class 'spacy.tokens.doc.Doc'>
#
# ---
#
# Coronavirus: Vietnam stockpiles rice as outbreak spreads and food security concerns grow https://t.co/jgfbtlN67l
# <class 'spacy.tokens.doc.Doc'>
#
# ---
#
# Crafty ways to beat virus blues: Get creative with small-group workshops https://t.co/0g6cMcnWyX. Singapore.
# <class 'spacy.tokens.doc.Doc'>
#
# ---
#
# Stranded by coronavirus lockdown, India migrant workers walk home https://t.co/3MwNgNDCEY
# <class 'spacy.tokens.doc.Doc'>
#
# ---
#
# Brazil bars foreigners as President Bolsonaro urges end to social distancing https://t.co/fBsxnYe8lp
# <class 'spacy.tokens.doc.Doc'>
#
# ---
#
# Buzzzzzzzzz
#
# Stay at home.
#
# Buzzzzzzzzz
#
# https://t.co/X76EumA6qW. El Segundo, CA.
# <class 'spacy.tokens.doc.Doc'>
#
# ---
#
# Cat found infected with coronavirus in Belgium https://t.co/pdWlfyS8wd
# <class 'spacy.tokens.doc.Doc'>
#
# ---
#
# Why the US is leading the world in confirmed coronavirus cases https://t.co/yTu7DjtmPJ via @TOIWorld
#
# #CautionYesPanicNo #CoronavirusOutbreak #Covid19
# <class 'spacy.tokens.doc.Doc'>
#
# ---
#
# From @WSJopinion: To restart the economy, the government needs to set up immunity registries similar to those for childhood diseases, writes @BillCassidy and Dr. Christopher Mores https://t.co/chvBoDBlKo. New York, NY.
# <class 'spacy.tokens.doc.Doc'>
#
# ---
#
# The irresistible force of the coronavirus collided with the immovable object of the federation this week, revealing both the limits of prime ministerial authority, and the fragility of our very system of governance | ANALYSIS https://t.co/1LECMGnSYX. Melbourne, Australia.
# <class 'spacy.tokens.doc.Doc'>
#
# ---
#
# Activists from across the occupied territory have reported a spike in settler attacks since a state of emergency was declared due to the coronavirus pandemic https://t.co/ZMJwochLle. None.
# <class 'spacy.tokens.doc.Doc'>
#
# ---

# %% [markdown]
# ## Example 1: Bag of Words Approach with gensim
#
# Here we attempt a bag of words approach to each tweet, seeing what results we get.

# %% [markdown]
# ### Pre-processing the text

# %%
def token_processor():
    # list that holds processed tokens in string form
    processed_docs = []

    for doc in docs_with_gpe:        
        # creates list per doc
        doc_list = []

        for token in doc:
            # checks if the token is an alpha character (removes numerals and punctuation)
            if token.is_alpha is True:
                # checks if token is part of a stop list
                if token.is_stop is False:
                    # checks if token is URL-like
                    if token.like_url is False:
                        # lowercases each token (uses the spaCy token's lowercase attribute)
                        token_text = token.lemma_
                        token_text_lemma = token_text.lower()
                        doc_list.append(token_text_lemma)
        processed_docs.append(doc_list)

    return processed_docs

# %% [markdown]
# ### Creating and querying a corpus

# %%
from gensim.corpora.dictionary import Dictionary

def gensim_processor(processed_docs):
    # creates a Dictionary from the tokens in processed_docs
    dictionary = Dictionary(processed_docs)
    # list comprehension iterates over processed_docs to create a gensim mmCorpus
    # from dictionary
    corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
    return corpus, dictionary

# %% [markdown]
# ### Creating a bag-of-words
#
# Here we use the gensim corpus and dictionary to see the most common terms per document and across all documents. We can also use the dictionary to look up the terms.

# %%
import itertools
from collections import Counter
from collections import defaultdict

def bag_of_words(corpus, dictionary):
    # as an example, we will use the Shangri-La article as a reference
    doc = corpus[0]

    # sorting the doc for frequency
    bow_doc = sorted(doc, key=lambda w: w[1], reverse=True)

    # print the top 10 words in the document along with the count
    print('\n\ntop 10 words in document')
    for word_id, word_count in bow_doc[:10]:
        print(dictionary.get(word_id), word_count)

    # creates a defaultdict - defaultdict assigns default values to non-existent keys
    # and by supplying the argument 'int', we ensure that nonexistent keys are automatially 
    # assigned a default value of 0, making it ideal for storing the counts of words
    total_word_count = defaultdict(int)
    # itertools.chain.from_iterable() allows us to iterate through a set of sequences as 
    # if they were one continuious sequence - this lets us iterate through our 'corpus' 
    # object, which is a list of lists
    for word_id, word_count in itertools.chain.from_iterable(corpus):
        total_word_count[word_id] += word_count

    # creates a sorted list from the defaultdict 
    sorted_word_count = sorted(total_word_count.items(), key=lambda w: w[1], reverse=True)

    # prints the top 10 words across all documents, along with their count
    print('\n\ntop 10 words across all documents')
    for word_id, word_count in sorted_word_count[:10]:
        print(dictionary.get(word_id), word_count)

# %% [markdown]
# ### TF-IDF with gensim

# %%
from gensim.models.tfidfmodel import TfidfModel

def tfidf(corpus):
    # creates a new TfidfModel using the corpus
    tfidf = TfidfModel(corpus)
    
    # the weights for each token in doc [0]
    tfidf_weights = tfidf[corpus][0]
    
    # sorts the weights from highest to lowest
    sorted_tfidf_weights = sorted(tfidf_weights, key=lambda w: w[1], reverse=True)
    
    # prints the top 10 weighted words
    print('\n\ntop 10 TF-IDF weights in document')
    for term_id, weight in sorted_tfidf_weights[:10]:
        print(dictionary.get(term_id), weight)

# %% [markdown]
# #### Runner Cell

# %%
processed_docs = token_processor()
# print('processed token list\n\n', processed_docs, '\n\n--\n')

corpus, dictionary = gensim_processor(processed_docs)
# print('corpus[0]\n\n', corpus[0], '\n\n--\n')
# print('corpus\n\n', corpus, '\n\n--\n')

bag_of_words(corpus, dictionary)

tfidf(corpus)
# Out:
# top 10 words in document
# annually 1
# cancel 1
# coronavirus 1
# dialogue 1
# forum 1
# high 1
# hold 1
# la 1
# outbreak 1
# profile 1
#
#
# top 10 words across all documents
# coronavirus 34
# new 26
# say 13
# delhi 12
# world 12
# city 12
# york 10
# health 9
# case 8
# pandemic 8
#
#
# top 10 TF-IDF weights in document
# annually 0.29830820574180555
# cancel 0.29830820574180555
# dialogue 0.29830820574180555
# forum 0.29830820574180555
# hold 0.29830820574180555
# la 0.29830820574180555
# profile 0.29830820574180555
# shangri 0.29830820574180555
# high 0.2534083468013127
# regional 0.2534083468013127

# %% [markdown]
# ## Example 2: Using Supervised Learning with NLP with scikit-learn
#
# We will use the geometric features of the text to conduct machine learning and categorize our data.
#
# The steps in supervised learning are as follows:
# * collect and pre-processes data
# * determine a label (the things we want to learn, i.e., movie genres)
# @TOIBusiness https://t.co/HGKCL4S3DI. New Delhi., In 10 days, this teacher went from a mild fever to a medically induced coma https://t.co/BlxJwLkW3r. Washington, DC., RBI cuts rate by 75 bps, steepest in over 10 years; you can defer EMIs by 3 months https://t.co/d5RWjMhm2p via @TOIBusiness. New Delhi., Australia tightens quarantine rules to combat coronavirus, warns of fines https://t.co/0rRrycdkzi https://t.co/WQK53uFBZP, Dr. Nagarajan's visa only allows him to work at the South Carolina hospital that hired him. He wants to be near the outbreak's epicenter in New York — but a USCIS slowdown means he can't easily transfer his visa.
#
# "I wish I can go and help there," he said. https://t.co/itvUvBN0DB, Who PH celebs would love to be quarantined with https://t.co/TGyXWUbvqf. Makati City., Anthony Joshua’s Promoter Has a Plan for Boxing Match to Go Ahead https://t.co/4gCDhVj3a7. New York and the World., Coronavirus: Vietnam stockpiles rice as outbreak spreads and food security concerns grow https://t.co/jgfbtlN67l, Crafty ways to beat virus blues: Get creative with small-group workshops https://t.co/0g6cMcnWyX. Singapore., Stranded by coronavirus lockdown, India migrant workers walk home https://t.co/3MwNgNDCEY, Brazil bars foreigners as President Bolsonaro urges end to social distancing https://t.co/fBsxnYe8lp, Buzzzzzzzzz
#
# Stay at home.
#
# Buzzzzzzzzz
#
# https://t.co/X76EumA6qW. El Segundo, CA., Cat found infected with coronavirus in Belgium https://t.co/pdWlfyS8wd, Why the US is leading the world in confirmed coronavirus cases https://t.co/yTu7DjtmPJ via @TOIWorld
#
# #CautionYesPanicNo #CoronavirusOutbreak #Covid19, From @WSJopinion: To restart the economy, the government needs to set up immunity registries similar to those for childhood diseases, writes @BillCassidy and Dr. Christopher Mores https://t.co/chvBoDBlKo. New York, NY., The irresistible force of the coronavirus collided with the immovable object of the federation this week, revealing both the limits of prime ministerial authority, and the fragility of our very system of governance | ANALYSIS https://t.co/1LECMGnSYX. Melbourne, Australia., Activists from across the occupied territory have reported a spike in settler attacks since a state of emergency was declared due to the coronavirus pandemic https://t.co/ZMJwochLle. None.]

# %% [markdown]
# #### Pre-processing the text

# %%
def token_processor():
    # list that holds processed tokens in string form
    processed_docs = []

    for doc in docs_with_gpe:        
        # creates list per doc
        doc_list = []

        for token in doc:
            # checks if the token is an alpha character (removes numerals and punctuation)
            if token.is_alpha is True:
                # checks if token is part of a stop list
                if token.is_stop is False:
                    # checks if token is URL-like
                    if token.like_url is False:
                        # lowercases each token (uses the spaCy token's lowercase attribute)
                        token_text = token.lemma_
                        token_text_lemma = token_text.lower()
                        doc_list.append(token_text_lemma)
                
        processed_docs.append(doc_list)

    return processed_docs

print(type(processed_docs))
print(type(processed_docs[0]))
print((processed_docs[0]))
# Out:
# <class 'list'>
# <class 'list'>
# ['shangri', 'la', 'dialogue', 'high', 'profile', 'regional', 'security', 'forum', 'hold', 'annually', 'singapore', 'cancel', 'coronavirus', 'outbreak']

# %%
import pandas as pd

def list_to_dataframe(processed_tokens_list):
    
    processed_tokens_strings = []
    
    for doc in processed_tokens_list:
        processed_tokens_strings.append(' '.join(token for token in doc))
    
    for doc in processed_tokens_strings:
        print(doc)
        print(type(doc))
        print('---')    
    
    df = pd.DataFrame(processed_tokens_strings)
    return df

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

# loads data into a pandas DataFrame
# df = ...

# y is traditionally the labels or outcome we want to model to learn

# %%
processed_tokens_list = token_processor()

df = list_to_dataframe(processed_tokens_list)
print(df.head())
# Out:
# shangri la dialogue high profile regional security forum hold annually singapore cancel coronavirus outbreak
# <class 'str'>
# ---
# nstnation non compliance movement control order mco lead case state say sabah health department director datuk dr christina rundi stayathome dudukrumah malaysia
# <class 'str'>
# ---
# dr sirous asgari accuse steal trade secret break washington sanction iran work research project case western reserve university ohio
# <class 'str'>
# ---
# okinawa see fall foreign visitor amid pandemic
# <class 'str'>
# ---
# new date tokyo will satisfy everybody say read cautionyespanicno tokyoolympics olympics sebastiancoe worldathletics coronavirus new delhi
# <class 'str'>
# ---
# trump invoke defense production act require general motors build ventilator coronavirus patient act give president power expand industrial production key material product world
# <class 'str'>
# ---
# coronavirus kiwi man offer dettol sanitiser bottle new zealand
# <class 'str'>
# ---
# nstsports dybala say leave struggle breath malaysia
# <class 'str'>
# ---
# nstnation health ministry set special committee conduct audit patient succumb hospital malaysia
# <class 'str'>
# ---
# european airline resist mount coronavirus refund claim world
# <class 'str'>
# ---
# headline hour visit new delhi
# <class 'str'>
# ---
# coronavirus india set join world health organisation multi country solidarity trial aim rapid global search drug treat
# <class 'str'>
# ---
# blue chip hardest hit foreign exit kenya
# <class 'str'>
# ---
# take rbi try arrest economic slide read today toi edit new delhi
# <class 'str'>
# ---
# nstworld watch paris opera singer belt balcony tune amid lockdown
# <class 'str'>
# ---
# patriotism self protection midst pandemic demand temporary ban overseas deployment filipino healthcare professional worker like physician nurse laboratory technician lagman say makati city
# <class 'str'>
# ---
# nstworld member congress test positive coronavirus dozen say self quarantine hope limit spread pandemic
# <class 'str'>
# ---
# sustain trust resilient real estate makati city
# <class 'str'>
# ---
# federal judge california consider emergency order release child apprehend cross order protect contract
# <class 'str'>
# ---
# nstworld brunei report coronavirus death saturday old man
# <class 'str'>
# ---
# milan hospital coronavirus squad battle odd save life
# <class 'str'>
# ---
# work unique time help stay ground new york city worldwide
# <class 'str'>
# ---
# share birthday ladygaga new delhi
# <class 'str'>
# ---
# softbank say obligate deal new york world
# <class 'str'>
# ---
# world war ii inspire poster remind stay inside wash hand washington dc
# <class 'str'>
# ---
# print today italy surpass china infection india urban poor fight survival false belief poison fight virus kill hundred iran
# <class 'str'>
# ---
# woman michigan trump say discuss pence white house coronavirus task force work governor gretchen whitmer reply twitter right need focus fight virus
# <class 'str'>
# ---
# house panel oversee coronavirus aid law expenditure pelosi world
# <class 'str'>
# ---
# coronavirus personal nightmare people ocd anxiety disorder new york ny
# <class 'str'>
# ---
# state attorney general say week flood complaint price gouging profiteering item like hand sanitizer disinfectant wipe mask
# <class 'str'>
# ---
# manhattan crowd disappear leave shuttered business rush hour sound hvac system audible quiet street
# <class 'str'>
# ---
# commentary leave data analysis expert tokyo
# <class 'str'>
# ---
# word betrayal traitor popular one social medium describe gantz breach faith
